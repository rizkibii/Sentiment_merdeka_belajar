# %%
import pandas as pd

# %%
df = pd.read_csv("corpus.csv", sep=';' )
df
# Out:
#       no        kata            replace
# 0      1         aku               saya
# 1      2         loe               kamu
# 2      3      jahatt              jahat
# 3      4      aamiin               amin
# 4      5        abah               ayah
# 5      6        abis              habis
# 6      7         abs  asal bapak senang
# 7      8          ad                ada
# 8      9        adem             dingin
# 9     10         adi               adik
# 10    11         adl             adalah
# 11    12        adlh             adalah
# 12    13   agreement        persetujuan
# 13    14          ah             kecewa
# 14    15     ahahaha            tertawa
# 15    16         aja             jangan
# 16    17        akyu               saya
# 17    18        also               juga
# 18    19  alutisista          alutsista
# 19    20    alutista          alutsista
# 20    21         ama                dan
# 21    22      amiinn               amin
# ...
