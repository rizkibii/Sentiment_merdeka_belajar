# %%
import pandas as pd
import joblib

import os
import sys
alamat = "/".join(os.getcwd().split("\\")[:-2])
sys.path.append(alamat+'/praproses')
from sklearn.metrics import accuracy_score

# %%
df = pd.read_excel("data/tweet_bersih_100.xlsx") #data latih yang digunakan tweet_bersih_100.xlsx
twet = df.tweet.tolist()
label = df.label.tolist()
df.head() #menampilkan lima teraatas dari data bersih
# Out:
#    Unnamed: 0                                              tweet     label
# 0           0  buka visi misi begitu pukau sehingga buat pres...  positive
# 1           1  lebih baik pakai teknologi lama kaya negara in...  positive
# 2           2                         kok arguing without menang  positive
# 3           3  jalan politik politik satu bukan politik pecah...  positive
# 4           4               juga fans lihat tampil serang hahaha  negative

# %%
pd.value_counts(df['label']).plot.bar(title='Data Sentimen')
print(pd.value_counts(df['label']))
# Out:
# positive    719
# negative    681
# Name: label, dtype: int64

# %%
import numpy as np
from sklearn.model_selection import KFold
from Naive_Bayes_ import naive_bayes_ as nb
X = np.array(twet)
y = np.array(label)

# %%
k = 10
y = np.array(label)
kf = KFold(n_splits=k) #membuat model kfold sejumlah k
kf.get_n_splits(X)


# print(kf)
alpah_list = np.arange(0.1, 10+.1, .1)
rerata = list()
for alpha in alpah_list:
    print(str(alpha), end= "")
    clf = nb.NaiveBayesClassifier(alpha = alpha)
    sc_10 = list()
    for train_index, test_index in kf.split(X):
        print(".", end="")
    #     print("TRAIN:", train_index, "TEST:", test_index)
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        clf.train(X_train, y_train)

        
        y_pred = clf.predict(X_test)
        y_true = y_test
        
        sc = accuracy_score(y_true, y_pred)
        sc_10.append(sc)
#     print( sum(sc_10)/k, "|", alpha)
    rerata.append(sum(sc_10)/k)
    print(sum(sc_10)/k)
dict_ = {
    "alpha":alpah_list,
    "score":rerata
}
df_hasil = pd.DataFrame.from_dict(dict_)
sorted_ = df_hasil.sort_values("score", axis = 0, ascending = False)
sorted_.head()
# Out:
# 0.1..........0.6957142857142855
# 0.2..........0.6978571428571427
# 0.30000000000000004..........0.6985714285714285
# 0.4..........0.6978571428571428
# 0.5..........0.6971428571428572
# 0.6..........0.6950000000000001
# 0.7000000000000001..........0.6957142857142856
# 0.8..........0.6942857142857142
# 0.9..........0.6935714285714285
# 1.0..........0.6921428571428571
# 1.1..........0.6907142857142856
# 1.2000000000000002..........0.6914285714285714
# 1.3000000000000003..........0.6885714285714285
# 1.4000000000000001..........0.6914285714285714
# 1.5000000000000002..........0.6914285714285714
# 1.6..........0.6892857142857143
# 1.7000000000000002..........0.69
# 1.8000000000000003..........0.6892857142857143
# 1.9000000000000001..........0.6892857142857143
# 2.0..........0.6892857142857143
# 2.1..........0.6892857142857143
# 2.2..........0.6885714285714285
# 2.3000000000000003..........0.6864285714285714
# 2.4000000000000004..........0.687142857142857
# 2.5000000000000004..........0.687142857142857
# 2.6..........0.6849999999999999
# 2.7..........0.6835714285714285
# 2.8000000000000003..........0.6842857142857143
# 2.9000000000000004..........0.6835714285714285
# 3.0000000000000004..........0.6835714285714285
# 3.1..........0.682142857142857
# 3.2..........0.6814285714285714
# 3.3000000000000003..........0.6814285714285714
# 3.4000000000000004..........0.6814285714285714
# 3.5000000000000004..........0.682142857142857
# 3.6..........0.6821428571428572
# 3.7..........0.6799999999999999
# 3.8000000000000003..........0.6807142857142857
# 3.9000000000000004..........0.6799999999999999
# 4.0..........0.6807142857142857
# 4.1..........0.6792857142857142
# 4.2..........0.6792857142857142
# 4.3..........0.6785714285714286
# 4.3999999999999995..........0.6785714285714286
# 4.5..........0.6792857142857143
# 4.6..........0.6785714285714285
# 4.7..........0.6771428571428572
# 4.8..........0.6771428571428572
# 4.9..........0.6764285714285714
# 5.0..........0.6764285714285714
# 5.1..........0.6757142857142856
# 5.2..........0.6757142857142856
# 5.3..........0.6749999999999999
# 5.4..........0.6749999999999999
# 5.5..........0.6749999999999999
# 5.6..........0.6735714285714285
# 5.7..........0.6742857142857142
# 5.8..........0.6749999999999999
# 5.9..........0.672142857142857
# 6.0..........0.672142857142857
# 6.1..........0.672142857142857
# 6.2..........0.6728571428571428
# 6.3..........0.6735714285714285
# 6.4..........0.6728571428571428
# 6.5..........0.6735714285714285
# 6.6..........0.6742857142857142
# 6.7..........0.6742857142857142
# 6.8..........0.6742857142857142
# 6.9..........0.6735714285714285
# 7.0..........0.6742857142857142
# 7.1..........0.6742857142857142
# 7.2..........0.6742857142857142
# 7.3..........0.6742857142857142
# 7.4..........0.6735714285714285
# 7.5..........0.6735714285714285
# 7.6..........0.6735714285714285
# 7.7..........0.6728571428571428
# 7.8..........0.6721428571428569
# 7.9..........0.6721428571428569
# 8.0..........0.6707142857142856
# 8.1..........0.672142857142857
# 8.2..........0.6714285714285714
# 8.3..........0.6714285714285714
# 8.4..........0.6714285714285714
# 8.5..........0.6714285714285714
# 8.6..........0.6714285714285714
# 8.7..........0.6714285714285714
# 8.8..........0.672142857142857
# 8.9..........0.6728571428571428
# 9.0..........0.6714285714285714
# 9.1..........0.6707142857142856
# 9.2..........0.6714285714285714
# 9.3..........0.6714285714285714
# 9.4..........0.6714285714285714
# 9.5..........0.6714285714285714
# 9.6..........0.6707142857142856
# 9.700000000000001..........0.6707142857142856
# 9.8..........0.6699999999999999
# 9.9..........0.6692857142857143
# 10.0..........0.6707142857142856
#    alpha     score
# 2    0.3  0.698571
# 3    0.4  0.697857
# 1    0.2  0.697857
# 4    0.5  0.697143
# 6    0.7  0.695714

# %%
sorted_.alpha.tolist()[0]
# Out:
# 0.30000000000000004

# %%
clf = nb.NaiveBayesClassifier(alpha = sorted_.alpha.tolist()[0])
clf.train(X, y) 
joblib.dump(clf,"model/naive_bayes.m")
# Out:
# ['model/naive_bayes.m']

# %%
x = clf.predict(X)

# %%
ixx = 0
labelA = list()
labelP= list()

for i, j in zip(label, x):
    if i !=j:
        print(ixx)
        print(j)
        print("label asli",i)
        print(twet[ixx])
        print()
    ixx+=1
# Out:
# 7
# negative
# label asli positive
# apa bilang pak memang benar mau bukti di ejek asing v i r a l k a n prabow
#
# 25
# negative
# label asli positive
# pak percaya sama tni iya pak percaya saya percaya nya sama orang suka ngomong bayar
#
# 38
# negative
# label asli positive
# si bilang bela pancasila dukung curut khilafah hti juga hapal pancasila
#
# 52
# negative
# label asli positive
# duh pak baik banget kalau bicara bahasa inggris arti tahu kalau pak bisa bahasa inggris
#
# 82
# negative
# label asli positive
# sorot debatpilpres 2019 kali presiden sangat jelas masa kini masa depan realita solusi masalah
#
# 99
# positive
# label asli negative
# tuju sekali pak selesai soal korupsi memang benah sistem bisa potong rantai
#
# 115
# negative
# label asli positive
# kalau mau jadi nice guy jadi mediator monggo kalau juang indonesia hormat indonesia kuat
#
# 136
# negative
# label asli positive
# bukan emosi bos tegas tu nama nya jelas kan hadap orang buta hati nya
#
# 153
# negative
# label asli positive
# tertawa puas takut marah larang ingat pilih biar bebas tertawa batas
#
# 155
# negative
# label asli positive
# pak tekan soal kecil anggar tahan pak
#
# 173
# negative
# label asli positive
# sila kalian ketawa kaya bilang bocor lalu sekarang soal tahan kalian ketawa
#
# 177
# negative
# label asli positive
# manusia ada kubu tuh selalu akal sehat
#
# 189
# negative
# label asli positive
# tahan aman indonesia harga mati jenderal kalau dunia internasional lihat balik
#
# 212
# negative
# label asli positive
# tertawa tertawa larang sama pak debatpilpres 2019
#
# 221
# negative
# label asli positive
# kata pak bukan lemah kalah kuat yang lambat kalah yang cepat
#
# 226
# positive
# label asli negative
# insyallah allah menang indonesia jadi macan asia bukan cebong asia
#
# 281
# negative
# label asli positive
# kata p anggar tni harus naik n perlu tni kuat tahan wilayah
#
# 293
# negative
# label asli positive
# kaya suatu bangsa kalau jaga suatu kuat tahan kuat tidak mungkin
#
# 304
# positive
# label asli negative
# lebih tni tni bagus pak aku overdosis jadi makin mudah kami pilih presiden
#
# 335
# negative
# label asli positive
# jangan ketawa kalian ketawa tahan indonesia rapuh kalian ketawa lucu kok lucu kata
#
# 341
# positive
# label asli negative
# menang mbak sepenuh yakin pak menang
#
# 348
# negative
# label asli positive
# wowo kali ingat pak bapak hati para bisik bapak kena tahan
#
# 360
# positive
# label asli negative
# lihat pak percaya tni
#
# 365
# positive
# label asli negative
# alas pilih prabowo menang debat april coblos sandi
#
# 372
# negative
# label asli positive
# lebih tni banyak tni
#
# 378
# negative
# label asli positive
# buat tonton ketawa saat bilang bukan salah bapak tidak tau salah siapa
#
# 443
# positive
# label asli negative
# satu yakin tni satu pesimis jadi pemerintahandilan lanjut indonesia maju
#
# 468
# negative
# label asli positive
# hal perintah bukan teori soal bagaimana jalan perintah baik
#
# 487
# positive
# label asli negative
# tertawa tertawa larang pemerintahandilan 01dilanjutkan debatkeempatpilpres 2019
#
# 519
# positive
# label asli negative
# kata tni milik budaya asal bapak senang asal bapak senang ini efek pernah pecat tni
#
# 537
# negative
# label asli positive
# kaya suatu bangsa kalau jaga suatu kuat tahan kuat tidak mungkin -
#
# 541
# negative
# label asli positive
# tidak paham ekonomi investasi asing lingkup bisnis di-framing olah negara asai asing cara militan
#
# 581
# negative
# label asli positive
# pak trauma pecat tni begini ngomongnya justru pak sipil percaya sama tni
#
# 584
# positive
# label asli negative
# kritik solusi bagai kaca air keruh kerja beri solusi nyata tumbuh ekonomi
#
# 601
# negative
# label asli positive
# debatpilpres 2019 bagaimana mau maju tni kalau baru jadi mayor jangan udah pensiun sekarang jadi timses bapak
#
# 605
# negative
# label asli positive
# ketawa kalian ketawa tahan indonesia rapuh kalian ketawa lucu kok lucu ujar
#
# 627
# positive
# label asli negative
# kalau mandat akan bersih kuat lembaga perintah akan hilang korupsi indonesia
#
# 642
# positive
# label asli negative
# perintah dil digital layan sangat perlu
#
# 715
# negative
# label asli positive
# kasihan pak tahan ketawa pecatanlebihtnidaritni
#
# 716
# negative
# label asli positive
# rendah dukung tahana rupa bukti rupa bukti bila cara tak langsung sedang hukum publik
#
# 725
# positive
# label asli negative
# bang kalau jadi presiden siapa ibu negara apa benar kita jadi negara piatu
#
# 728
# positive
# label asli negative
# lihat pak percaya tni pemerintahandilan memang nampol
#
# 739
# negative
# label asli positive
# makanya jangan ragu prabowobentengnkri prabowobentengnkri
#
# 752
# positive
# label asli negative
# pak percaya yang pecatanlebihtnidaritni pecatanlebihtnidaritni https t co jrlvbdoafw
#
# 764
# positive
# label asli negative
# maju era android ke era pecatanlebihtnidaritni
#
# 805
# positive
# label asli negative
# malam minggu duduk depan layar tv nonton debat empat calon presiden semangat pak 01dilanjutkan
#
# 830
# positive
# label asli negative
# pak all keluar debat malam semua umpan lawan lahap habis bahkan jawab kerap jadi serang balik
#
# 847
# positive
# label asli negative
# awal gila antek antek dukung mulai pilpres mana hasil oleh suara sangat sedikit
#
# 858
# positive
# label asli negative
# apresiasi saudara di papua pakde jadi percuma kalian tebar bohong papua derita
#
# 860
# positive
# label asli negative
# satu yakin tni satu pesimis jadi pemerintahandilan lanjut indonesia maju
#
# 874
# positive
# label asli negative
# nyata pak debat empat ragu tni 01dilanjutkan jokowilagi
#
# 882
# positive
# label asli negative
# lama kawan lalu musuh lama tetangga lalu tak saling bicara semua karena beda pilih
#
# 888
# positive
# label asli negative
# rantai sahabat pak pak akan putus debatpilpres 2019 dengerin tuh tkn-bpn cebong kampret
#
# 893
# positive
# label asli negative
# jangan pilih pimpin bohong ingkar janji provokasi rakyat kacang lupa kulit pilih pimpin jujur
#
# 906
# positive
# label asli negative
# kalau mandat akan bersih kuat lembaga perintah akan hilang korupsi
#
# 968
# positive
# label asli negative
# mantap keren moga ikut seluruh pelosok nusantara
#
# 998
# positive
# label asli negative
# bukan tidak percaya ini tni pak taruh nyawa tni lebih tni tni
#
# 1016
# negative
# label asli positive
# rang pak un tidak apa apa
#
# 1029
# negative
# label asli positive
# mendikbud un bukan satu 2nya tolak ukur
#
# 1046
# negative
# label asli positive
# hapus
#
# 1047
# negative
# label asli positive
# dunia kerja skill terampil bidang masing - masing bukan angka ada lembar kertas
#
# 1049
# negative
# label asli positive
# hapus unfaedah
#
# 1051
# negative
# label asli positive
# sih ada orang sukses sampe sekarang dulu nya enggak pernah ikut uji even bill gates ttp uji pas masuk kuliah meski akhir enggak kelar
#
# 1058
# negative
# label asli positive
# malah buat siswa i hemat uang pak tidak pt pt beli kunci
#
# 1061
# positive
# label asli negative
# tuju un hapus
#
# 1070
# positive
# label asli negative
# tuju
#
# 1166
# positive
# label asli negative
# kurang kuota jalur zonasi ppdb http bit ly 2pgk85i
#
# 1171
# positive
# label asli negative
# ajar masih bias filosofi kemdikbud era jilid empat pilar usbn un rpp zonasi letak cetus bagai merdeka ajar pilar berapa usbn konsep kti un laku di kelas xi zonasi ppdb merdekabelajar
#
# 1242
# negative
# label asli positive
# kalau kayak gin makin banyak wktu keluarga
#
# 1278
# positive
# label asli negative
# jangan dulu seluruh indonesia fasilitas kualitas daerah jangan dulu pak benah buat guru honorer udah abdi lebih 10th tlng perhati sejahtera
#
# 1280
# positive
# label asli negative
# esensi rpp tuju giat ajar assesmen lembar
#
# 1282
# positive
# label asli negative
# rpp satu temu mungkin satu halaman lebih mungkin tetap jika rpp komponen holistik kaffah
#
# 1284
# positive
# label asli negative
# selain fungsi rencana cara tulis organisasi laksana evaluasi didik ajar buah giat perlu administrasi
#
# 1299
# positive
# label asli negative
# juknis contoh kongkritnya mas nadiem
#
# 1310
# negative
# label asli positive
# pasti ganti nya
#
# 1343
# positive
# label asli negative
# sebut liput uji sekolah standar nasional usbn uji nasional un rencana laksana ajar rpp atur terima didik baru ppdb zonasi hukumperusuhnegeri
#
# 1354
# positive
# label asli negative
# nan
#
# 1360
# positive
# label asli negative
# tahun soal uji usbn serah buat sekolah masing-masing
#
# 1363
# positive
# label asli negative
# jangan un maupun usbn
#
# 1365
# positive
# label asli negative
# instrument alat ukur hasil ajar bukan elemen bangun kualitas intelegensi bung mana materi kurikulum program bina moral haadeehh mas eyang bro jeng bagaimana nih https edukasi kompas com read 2019 12 11 14433351 ini-konsep-baru-un-dan-usbn-versi-merdeka-belajar-mendikbud-makarim
#
# 1372
# positive
# label asli negative
# dar wacana
#
# 1385
# positive
# label asli negative
# cara nilai survei karakter nilai objektif un sekarang kan tentu kelulus benar beban moga un ganti asasmen kompetensi turun semangat ajar siswa tidak un jadi tidak ajar
#
# 1388
# positive
# label asli negative
# dar wacana
