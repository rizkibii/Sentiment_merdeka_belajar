# %%
import pandas as pd
import joblib

# %%
df = pd.read_excel("data/tweet_bersih_100.xlsx") #data latih yang digunakan tweet_bersih_100.xlsx
twet = df.tweet.tolist()
label = df.label.tolist()
df.head() #menampilkan lima teraatas dari data bersih
# Out:
#    Unnamed: 0                                              tweet     label
# 0           0  buka visi misi begitu pukau sehingga buat pres...  positive
# 1           1  lebih baik pakai teknologi lama tetapi kaya ne...  positive
# 2           2                         kok arguing without menang  positive
# 3           3  jalan politik politik satu bukan politik pecah...  positive
# 4           4               juga fans lihat tampil serang hahaha  negative

# %%
pd.value_counts(df['label']).plot.bar(title='Data Sentimen')
print(pd.value_counts(df['label']))
# Out:
# positive    664
# negative    636
# Name: label, dtype: int64

# %%
import numpy as np
from sklearn.model_selection import KFold
from sklearn.naive_bayes import MultinomialNB

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
corpus = twet
vectorizer = TfidfVectorizer()
save = vectorizer.fit(corpus)
joblib.dump(save,"model/tdidf.w")
X = vectorizer.fit_transform(corpus)
len(vectorizer.get_feature_names())#jumlah line fitur
# Out:
# 3180

# %%
k = 10
y = np.array(label)
kf = KFold(n_splits=k) #membuat model kfold sejumlah k
kf.get_n_splits(X)
# print(kf)
alpah_list = np.arange(0.1, 1+0.001, 0.001)
rerata = list()
for alpha in alpah_list:
    clf = MultinomialNB(alpha = alpha)
    sc_10 = list()
    for train_index, test_index in kf.split(X):
    #     print("TRAIN:", train_index, "TEST:", test_index)
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        clf.fit(X_train, y_train)
        sc = clf.score(X_test, y_test)
        sc_10.append(sc)
#     print( sum(sc_10)/k, "|", alpha)
    rerata.append(sum(sc_10)/k)
dict_ = {
    "alpha":alpah_list,
    "score":rerata
}
df_hasil = pd.DataFrame.from_dict(dict_)
sorted_ = df_hasil.sort_values("score", axis = 0, ascending = False)
sorted_.head()
# Out:
#      alpha     score
# 298  0.398  0.736923
# 294  0.394  0.736923
# 295  0.395  0.736923
# 296  0.396  0.736923
# 297  0.397  0.736923

# %%
sorted_.alpha.tolist()[0]
# Out:
# 0.39800000000000024

# %%
clf = MultinomialNB(alpha = sorted_.alpha.tolist()[0])
save = clf.fit(X, y) 
joblib.dump(save,"model/naive_bayes.m")
# Out:
# ['model/naive_bayes.m']

# %%
save.score(X, y)
# Out:
# 0.9392307692307692

# %%
x = save.predict(X)

# %%
ixx = 0
labelA = list()
labelP= list()

for i, j in zip(label, x):
    if i !=j:
        print(ixx)
        print(j)
        print("label asli",i)
        print(twet[ixx])
        print()
    ixx+=1
# Out:
# 7
# negative
# label asli positive
# apa bilang pak memang benar mau bukti di ejek asing v i r a l k a n prabow
#
# 10
# negative
# label asli positive
# bidang hubung internasional anut prinsip kawan terlalu sedikit musuh terlalu banyak prabowo
#
# 25
# negative
# label asli positive
# pak percaya sama tni iya pak percaya saya tidak percaya nya sama orang suka ngomong bayar
#
# 38
# negative
# label asli positive
# si bilang bela pancasila dukung curut khilafah hti juga tidak hapal pancasila
#
# 52
# negative
# label asli positive
# duh pak baik banget kalau bicara bahasa inggris arti tahu kalau pak tidak bahasa inggris
#
# 82
# negative
# label asli positive
# sorot debatpilpres 2019 kali presiden sangat jelas masa kini masa depan realita solusi masalah
#
# 99
# positive
# label asli negative
# tuju sekali pak selesai soal korupsi memang benah sistem bisa potong rantai
#
# 114
# negative
# label asli positive
# mantep banget nih ustad tak perlu ganti presiden cukup pilih pak di tps
#
# 115
# negative
# label asli positive
# kalau mau jadi nice guy jadi mediator monggo kalau juang indonesia hormat indonesia kuat
#
# 119
# negative
# label asli positive
# bukan tidak percaya tni ini tni taruh nyawa di tni lebih tni banyak tni
#
# 153
# negative
# label asli positive
# tertawa puas takut marah larang tapi ingat pilih biar bebas tertawa batas
#
# 155
# negative
# label asli positive
# pak tekan soal kecil anggar tahan pak
#
# 173
# negative
# label asli positive
# sila kalian ketawa kaya bilang bocor lalu sekarang soal tahan kalian ketawa
#
# 177
# negative
# label asli positive
# manusia ada kubu tuh selalu akal sehat
#
# 189
# negative
# label asli positive
# tahan aman indonesia harga mati jenderal kalau dunia internasional lihat balik
#
# 212
# negative
# label asli positive
# tertawa tertawa larang sama pak debatpilpres 2019
#
# 221
# negative
# label asli positive
# kata pak bukan lemah kalah kuat tapi lambat kalah yang cepat
#
# 226
# positive
# label asli negative
# insyallah allah menang indonesia jadi macan asia bukan cebong asia
#
# 236
# negative
# label asli positive
# tukang kayu lebih ngerti militer yang pernah jadi militer lebih tni tni
#
# 281
# negative
# label asli positive
# kata p anggar tni harus naik n perlu tni kuat tahan wilayah
#
# 304
# positive
# label asli negative
# lebih tni tni bagus pak aku overdosis jadi makin mudah kami pilih presiden
#
# 311
# negative
# label asli positive
# pak all keluar debat malam semua umpan lawan lahap habis bahkan jawab kerap jadi serang balik
#
# 316
# negative
# label asli positive
# jadi keliru kalau badan menang nasional beri angin hti harap suara hti justru hti tidak percaya demokrasi
#
# 335
# negative
# label asli positive
# jangan ketawa kalian ketawa tahan indonesia rapuh kalian ketawa lucu kok lucu kata
#
# 341
# positive
# label asli negative
# menang mbak sepenuh yakin pak menang
#
# 348
# negative
# label asli positive
# wowo kali ingat pak bapak hati para bisik bapak kena tahan
#
# 360
# positive
# label asli negative
# lihat pak tidak percaya tni
#
# 365
# positive
# label asli negative
# alas pilih prabowo menang debat april coblos sandi
#
# 372
# negative
# label asli positive
# lebih tni banyak tni
#
# 378
# negative
# label asli positive
# buat tonton ketawa saat bilang bukan salah bapak tidak tau salah siapa
#
# 443
# positive
# label asli negative
# satu yakin tni satu pesimis jadi pemerintahandilan lanjut indonesia maju
#
# 468
# negative
# label asli positive
# hal perintah bukan teori soal bagaimana jalan perintah baik
#
# 487
# positive
# label asli negative
# tertawa tertawa larang pemerintahandilan 01dilanjutkan debatkeempatpilpres 2019
#
# 499
# negative
# label asli positive
# takar kadar pancasila harga mati calon presiden sini pak calon presiden pecat tni kok tidak pernah bilang dukung
#
# 519
# positive
# label asli negative
# kata tni milik budaya asal bapak senang asal bapak senang ini efek pernah pecat tni
#
# 541
# negative
# label asli positive
# tidak paham ekonomi investasi asing lingkup bisnis di-framing olah negara asai asing cara militan
#
# 581
# negative
# label asli positive
# pak trauma pecat tni begini ngomongnya justru pak sipil percaya sama tni
#
# 584
# positive
# label asli negative
# kritik solusi bagai kaca air keruh kerja beri solusi nyata tumbuh ekonomi
#
# 601
# negative
# label asli positive
# debatpilpres 2019 bagaimana mau maju tni kalau baru jadi mayor jangan udah pensiun sekarang jadi timses bapak
#
# 612
# negative
# label asli positive
# distrust nggak paham apa makna hanya plonga-plongo debatpilpres 2019 https t co qpr 2qpbcj1
#
# 627
# positive
# label asli negative
# kalau mandat akan bersih kuat lembaga perintah akan hilang korupsi indonesia
#
# 642
# positive
# label asli negative
# perintah dil digital layan sangat perlu
#
# 687
# positive
# label asli negative
# penting jangan asal bapak senang kata sindir prabowobentengnkri asal bapak senang tidak tau kondisi riil rakyat
#
# 715
# negative
# label asli positive
# kasihan pak tahan ketawa pecatanlebihtnidaritni
#
# 716
# negative
# label asli positive
# rendah dukung tahana rupa bukti rupa bukti bila cara tak langsung sedang hukum publik
#
# 725
# positive
# label asli negative
# bang kalau jadi presiden siapa ibu negara apa benar kita jadi negara piatu
#
# 728
# positive
# label asli negative
# lihat pak tidak percaya tni pemerintahandilan memang nampol
#
# 756
# positive
# label asli negative
# tetap sahabat pak sinyal siap siap bawa pulang kecebong solo
#
# 764
# positive
# label asli negative
# maju era android ke era pecatanlebihtnidaritni
#
# 789
# positive
# label asli negative
# pak kata kuat lembaga perintah hilang korupsi
#
# 805
# positive
# label asli negative
# malam minggu duduk depan layar tv nonton debat empat calon presiden semangat pak 01dilanjutkan
#
# 858
# positive
# label asli negative
# apresiasi saudara di papua pakde jadi percuma kalian tebar bohong papua derita
#
# 860
# positive
# label asli negative
# satu yakin tni satu pesimis jadi pemerintahandilan lanjut indonesia maju
#
# 874
# positive
# label asli negative
# nyata pak debat empat ragu tni 01dilanjutkan jokowilagi
#
# 882
# positive
# label asli negative
# lama kawan lalu musuh lama tetangga lalu tak saling bicara semua karena beda pilih
#
# 888
# positive
# label asli negative
# rantai sahabat pak pak tidak putus debatpilpres 2019 dengerin tuh tkn-bpn cebong kampret
#
# 893
# positive
# label asli negative
# jangan pilih pimpin bohong ingkar janji provokasi rakyat kacang lupa kulit pilih pimpin jujur
#
# 906
# positive
# label asli negative
# kalau mandat akan bersih kuat lembaga perintah akan hilang korupsi
#
# 968
# positive
# label asli negative
# mantap keren moga ikut seluruh pelosok nusantara
#
# 998
# positive
# label asli negative
# bukan tidak percaya ini tni pak taruh nyawa tni lebih tni tni
#
# 1000
# negative
# label asli positive
# rang pak un tidak apa apa
#
# 1014
# negative
# label asli positive
# mendikbud hapus un mesti tahu sudah hapus kurikulum dasar perlu tinjau
#
# 1035
# negative
# label asli positive
# sih ada orang sukses sampe sekarang dulu nya enggak pernah ikut uji even bill gates ttp uji pas masuk kuliah meski akhir enggak kelar
#
# 1051
# positive
# label asli negative
# wajib bagai tolok ukur tingkat hasil proses ajar ajar nasional bukan bagai acu kelulus pertahankanun
#
# 1076
# negative
# label asli positive
# adik ku risau sistem zonasi kayak tidak sama kemapuan sendiri padahal kalau kalian dapat nilai rata rata atas pada bakal struggle sekolah kata tidak favorit unpopularopinion zonasi ppdb
#
# 1096
# positive
# label asli negative
# ppdb turun jadi persen https andalannews com kuota-zonasi-di-ppdb-turun-jadi - 50 - persen 21073 pic twitter com xlugmqrqvv
#
# 1100
# positive
# label asli negative
# gugat ma tolak uji materi zonasi ppdb https tribunasia com index php 2019 12 11 fsgi-apresiasi-gugatan-ma-tolak-uji-materi-zonasi-ppdb pic twitter com r8uhwvnqau
#
# 1106
# positive
# label asli negative
# hapus dari agenda didik indonesia tidak relevan dengan sistem zonasi terima didik badu ppdb mulai tahun kemarin laksana serentak buat gejolak masyarakat ubaid matraji ujiannasional pic twitter com a82lagphug
#
# 1115
# positive
# label asli negative
# ajar masih bias filosofi kemdikbud era jilid empat pilar usbn un rpp zonasi letak cetus bagai merdeka ajar pilar berapa usbn konsep kti un laku di kelas xi zonasi ppdb merdekabelajar
#
# 1124
# positive
# label asli negative
# kalau kait nilai bagus bijak depan tidak bakal orientasi nilai bukti proporsi jatah siswa tambah buat jalur afirmasi bukan nambah jalur prestasi jadi semangat perata mutu didik sih bakal tetap
#
# 1136
# positive
# label asli negative
# suara selamat nikmat hidang musikalisasi curah hati ajar kena sistem zonasi moga mudah erti
#
# 1191
# positive
# label asli negative
# akan sederhana isi raport lebih sederhana cair tf lebih tepat waktu
#
# 1203
# positive
# label asli negative
# selain fungsi rencana cara tulis organisasi laksana evaluasi didik ajar buah giat perlu administrasi
#
# 1217
# positive
# label asli negative
# paham lembar format tidak soal format hanya cara kerja gurita birokrasi mecengkram guru siswa
#
# 1218
# positive
# label asli negative
# juknis contoh kongkritnya mas nadiem
#
# 1220
# negative
# label asli positive
# tapi ada ganti nya
#
# 1253
# positive
# label asli negative
# sebut liput uji sekolah standar nasional usbn uji nasional un rencana laksana ajar rpp atur terima didik baru ppdb zonasi hukumperusuhnegeri
#
# 1265
# positive
# label asli negative
# instrument alat ukur hasil ajar bukan elemen bangun kualitas intelegensi bung mana materi kurikulum program bina moral haadeehh mas eyang bro jeng bagaimana nih https edukasi kompas com read 2019 12 11 14433351 ini-konsep-baru-un-dan-usbn-versi-merdeka-belajar-mendikbud-makarim
#
# 1285
# positive
# label asli negative
# cara nilai survei karakter nilai objektif un sekarang kan tidak kelulus benar tidak beban moga un ganti asasmen kompetensi tidak turun semangat ajar siswa tidak un jadi tidak ajar
