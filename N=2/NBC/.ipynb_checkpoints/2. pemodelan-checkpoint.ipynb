# %%
import pandas as pd
import joblib

import os
import sys
alamat = "/".join(os.getcwd().split("\\")[:-2])
sys.path.append(alamat+'/praproses')
from sklearn.metrics import accuracy_score

# %%
df = pd.read_excel("data/tweet_bersih_100.xlsx") #data latih yang digunakan tweet_bersih_100.xlsx
twet = df.tweet.tolist()
label = df.label.tolist()
df.head() #menampilkan lima teraatas dari data bersih
# Out:
#    Unnamed: 0                                              tweet     label
# 0           0  buka visi misi begitu pukau sehingga buat pres...  positive
# 1           1  lebih baik pakai teknologi lama kaya negara in...  positive
# 2           2                         kok arguing without menang  positive
# 3           3  jalan politik politik satu bukan politik pecah...  positive
# 4           4               juga fans lihat tampil serang hahaha  negative

# %%
pd.value_counts(df['label']).plot.bar(title='Data Sentimen')
print(pd.value_counts(df['label']))
# Out:
# negative    500
# positive    500
# Name: label, dtype: int64

# %%
import numpy as np
from sklearn.model_selection import KFold
from Naive_Bayes_ import naive_bayes_ as nb
X = np.array(twet)
y = np.array(label)

# %%
k = 10
y = np.array(label)
kf = KFold(n_splits=k) #membuat model kfold sejumlah k
kf.get_n_splits(X)


# print(kf)
alpah_list = np.arange(0.1, 10+.1, .1)
rerata = list()
for alpha in alpah_list:
    print(str(alpha), end= "")
    clf = nb.NaiveBayesClassifier(alpha = alpha)
    sc_10 = list()
    for train_index, test_index in kf.split(X):
        print(".", end="")
    #     print("TRAIN:", train_index, "TEST:", test_index)
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        clf.train(X_train, y_train)

        
        y_pred = clf.predict(X_test)
        y_true = y_test
        
        sc = accuracy_score(y_true, y_pred)
        sc_10.append(sc)
#     print( sum(sc_10)/k, "|", alpha)
    rerata.append(sum(sc_10)/k)
    print(sum(sc_10)/k)
dict_ = {
    "alpha":alpah_list,
    "score":rerata
}
df_hasil = pd.DataFrame.from_dict(dict_)
sorted_ = df_hasil.sort_values("score", axis = 0, ascending = False)
sorted_.head()
# Out:
# 0.1..........0.74
# 0.2..........0.736
# 0.30000000000000004..........0.7390000000000001
# 0.4..........0.74
# 0.5..........0.7390000000000001
# 0.6..........0.7379999999999999
# 0.7000000000000001..........0.741
# 0.8..........0.743
# 0.9..........0.7430000000000001
# 1.0..........0.7420000000000001
# 1.1..........0.74
# 1.2000000000000002..........0.743
# 1.3000000000000003..........0.743
# 1.4000000000000001..........0.745
# 1.5000000000000002..........0.748
# 1.6..........0.7489999999999999
# 1.7000000000000002..........0.7489999999999999
# 1.8000000000000003..........0.7489999999999999
# 1.9000000000000001..........0.7509999999999999
# 2.0..........0.7499999999999999
# 2.1..........0.7479999999999999
# 2.2..........0.7470000000000001
# 2.3000000000000003..........0.746
# 2.4000000000000004..........0.744
# 2.5000000000000004..........0.744
# 2.6..........0.743
# 2.7..........0.743
# 2.8000000000000003..........0.741
# 2.9000000000000004..........0.741
# 3.0000000000000004..........0.741
# 3.1..........0.741
# 3.2..........0.7390000000000001
# 3.3000000000000003..........0.7380000000000001
# 3.4000000000000004..........0.7370000000000001
# 3.5000000000000004..........0.7370000000000001
# 3.6..........0.734
# 3.7..........0.732
# 3.8000000000000003..........0.7310000000000001
# 3.9000000000000004..........0.7310000000000001
# 4.0..........0.732
# 4.1..........0.732
# 4.2..........0.733
# 4.3..........0.734
# 4.3999999999999995..........0.733
# 4.5..........0.733
# 4.6..........0.732
# 4.7..........0.7300000000000001
# 4.8..........0.7300000000000001
# 4.9..........0.729
# 5.0..........0.729
# 5.1..........0.73
# 5.2..........0.731
# 5.3..........0.731
# 5.4..........0.731
# 5.5..........0.731
# 5.6..........0.7310000000000001
# 5.7..........0.7310000000000001
# 5.8..........0.7310000000000001
# 5.9..........0.7300000000000001
# 6.0..........0.7300000000000001
# 6.1..........0.7300000000000001
# 6.2..........0.7300000000000001
# 6.3..........0.7300000000000001
# 6.4..........0.7300000000000001
# 6.5..........0.7300000000000001
# 6.6..........0.7300000000000001
# 6.7..........0.7290000000000001
# 6.8..........0.7290000000000001
# 6.9..........0.7290000000000001
# 7.0..........0.7300000000000001
# 7.1..........0.7300000000000001
# 7.2..........0.7290000000000001
# 7.3..........0.7300000000000001
# 7.4..........0.7300000000000001
# 7.5..........0.7310000000000001
# 7.6..........0.733
# 7.7..........0.731
# 7.8..........0.731
# 7.9..........0.731
# 8.0..........0.731
# 8.1..........0.731
# 8.2..........0.731
# 8.3..........0.731
# 8.4..........0.73
# 8.5..........0.73
# 8.6..........0.73
# 8.7..........0.73
# 8.8..........0.73
# 8.9..........0.73
# 9.0..........0.73
# 9.1..........0.7289999999999999
# 9.2..........0.728
# 9.3..........0.728
# 9.4..........0.728
# 9.5..........0.728
# 9.6..........0.727
# 9.700000000000001..........0.726
# 9.8..........0.724
# 9.9..........0.7230000000000001
# 10.0..........0.7230000000000001
#     alpha  score
# 18    1.9  0.751
# 19    2.0  0.750
# 17    1.8  0.749
# 16    1.7  0.749
# 15    1.6  0.749

# %%
sorted_.alpha.tolist()[0]
# Out:
# 1.9000000000000001

# %%
clf = nb.NaiveBayesClassifier(alpha = sorted_.alpha.tolist()[0])
clf.train(X, y) 
joblib.dump(clf,"model/naive_bayes.m")
# Out:
# ['model/naive_bayes.m']

# %%
x = clf.predict(X)

# %%
ixx = 0
labelA = list()
labelP= list()

for i, j in zip(label, x):
    if i !=j:
        print(ixx)
        print(j)
        print("label asli",i)
        print(twet[ixx])
        print()
    ixx+=1
# Out:
# 7
# negative
# label asli positive
# apa bilang pak memang benar mau bukti di ejek asing v i r a l k a n prabow
#
# 10
# negative
# label asli positive
# bidang hubung internasional anut prinsip kawan terlalu sedikit musuh terlalu banyak prabowo
#
# 17
# positive
# label asli negative
# debat malam bukti sama emosional emosi pikir selamat
#
# 25
# negative
# label asli positive
# pak percaya sama tni iya pak percaya saya percaya nya sama orang suka ngomong bayar
#
# 38
# negative
# label asli positive
# si bilang bela pancasila dukung curut khilafah hti juga hapal pancasila
#
# 43
# positive
# label asli negative
# ini tni pak pecat debatpilpres 2019 https t co usdobwdlba
#
# 51
# positive
# label asli negative
# menang telak sih gilee bantai cara telak debat gilak brutal malam
#
# 52
# negative
# label asli positive
# duh pak baik banget kalau bicara bahasa inggris arti tahu kalau pak bisa bahasa inggris
#
# 82
# negative
# label asli positive
# sorot debatpilpres 2019 kali presiden sangat jelas masa kini masa depan realita solusi masalah
#
# 99
# positive
# label asli negative
# tuju sekali pak selesai soal korupsi memang benah sistem bisa potong rantai
#
# 109
# negative
# label asli positive
# optimisindonesiamaju kalau tetap percaya sama orang walau sering tuduh itu hehe
#
# 114
# negative
# label asli positive
# mantep banget nih ustad tak perlu ganti presiden cukup pilih pak di tps
#
# 115
# negative
# label asli positive
# kalau mau jadi nice guy jadi mediator monggo kalau juang indonesia hormat indonesia kuat
#
# 119
# negative
# label asli positive
# bukan tidak percaya tni ini tni taruh nyawa di tni lebih tni banyak tni
#
# 131
# negative
# label asli positive
# ucap orang prajurit tak ragu tulus prabowo
#
# 153
# negative
# label asli positive
# tertawa puas takut marah larang ingat pilih biar bebas tertawa batas
#
# 155
# negative
# label asli positive
# pak tekan soal kecil anggar tahan pak
#
# 173
# negative
# label asli positive
# sila kalian ketawa kaya bilang bocor lalu sekarang soal tahan kalian ketawa
#
# 177
# negative
# label asli positive
# manusia ada kubu tuh selalu akal sehat
#
# 181
# positive
# label asli negative
# buzzer bayar siap ikut polling nih rakyat mau lawan lihat siapa menang prabowo
#
# 189
# negative
# label asli positive
# tahan aman indonesia harga mati jenderal kalau dunia internasional lihat balik
#
# 211
# negative
# label asli positive
# kalau bicara nasionalisme p semangat jangan ketawa lemah itu reaksi spontan patriotik
#
# 221
# negative
# label asli positive
# kata pak bukan lemah kalah kuat yang lambat kalah yang cepat
#
# 226
# positive
# label asli negative
# insyallah allah menang indonesia jadi macan asia bukan cebong asia
#
# 236
# negative
# label asli positive
# tukang kayu lebih ngerti militer yang pernah jadi militer lebih tni tni
#
# 281
# negative
# label asli positive
# kata p anggar tni harus naik n perlu tni kuat tahan wilayah
#
# 290
# negative
# label asli positive
# pak tadi maju tidak pakai teks gestur di luar kepala lulus fort cantik gitu
#
# 293
# negative
# label asli positive
# kaya suatu bangsa kalau jaga suatu kuat tahan kuat tidak mungkin
#
# 297
# positive
# label asli negative
# pilpres tarung akal sehat akal dungu jokowidiambangkekalahan https t co 0ygyvuuior
#
# 304
# positive
# label asli negative
# lebih tni tni bagus pak aku overdosis jadi makin mudah kami pilih presiden
#
# 335
# negative
# label asli positive
# jangan ketawa kalian ketawa tahan indonesia rapuh kalian ketawa lucu kok lucu kata
#
# 341
# positive
# label asli negative
# menang mbak sepenuh yakin pak menang
#
# 348
# negative
# label asli positive
# wowo kali ingat pak bapak hati para bisik bapak kena tahan
#
# 360
# positive
# label asli negative
# lihat pak percaya tni
#
# 365
# positive
# label asli negative
# alas pilih prabowo menang debat april coblos sandi
#
# 372
# negative
# label asli positive
# lebih tni banyak tni
#
# 377
# positive
# label asli negative
# lihat pak percaya tni telak sekali bro tak kutik
#
# 378
# negative
# label asli positive
# buat tonton ketawa saat bilang bukan salah bapak tidak tau salah siapa
#
# 397
# negative
# label asli positive
# dong selalu fokus masalah bicara perlu banyak kerja kepoinpemilu jokowimengubahsemua
#
# 438
# negative
# label asli positive
# apresiasi saudara di papua pakde jadi percuma kalian tebar bohong papua derita
#
# 443
# positive
# label asli negative
# satu yakin tni satu pesimis jadi pemerintahandilan lanjut indonesia maju
#
# 487
# positive
# label asli negative
# tertawa tertawa larang pemerintahandilan 01dilanjutkan debatkeempatpilpres 2019
#
# 499
# negative
# label asli positive
# takar kadar pancasila harga mati calon presiden sini pak calon presiden pecat tni kok pernah bilang dukung
#
# 537
# negative
# label asli positive
# kaya suatu bangsa kalau jaga suatu kuat tahan kuat tidak mungkin -
#
# 541
# negative
# label asli positive
# tidak paham ekonomi investasi asing lingkup bisnis di-framing olah negara asai asing cara militan
#
# 542
# positive
# label asli negative
# wow pakai bahasa inggris debat buat plonga plongo https t co chujvskyv 4 prabowomenangdebat
#
# 547
# positive
# label asli negative
# jadi presiden berat biar pak prabowobentengnkri jokowidiambangkekalahan https t co ehlgdl 2mcx
#
# 556
# positive
# label asli negative
# dengar pak meski sangat lambat https t co aydhf 1aca7
#
# 562
# positive
# label asli negative
# malam pak tampil serang lugas skakmaat
#
# 577
# positive
# label asli negative
# korupsi parah stadium empat https t co 4sqd2cyjnw prabowobentengnkri
#
# 581
# negative
# label asli positive
# pak trauma pecat tni begini ngomongnya justru pak sipil percaya sama tni
#
# 584
# positive
# label asli negative
# kritik solusi bagai kaca air keruh kerja beri solusi nyata tumbuh ekonomi
#
# 601
# negative
# label asli positive
# debatpilpres 2019 bagaimana mau maju tni kalau baru jadi mayor jangan udah pensiun sekarang jadi timses bapak
#
# 605
# negative
# label asli positive
# ketawa kalian ketawa tahan indonesia rapuh kalian ketawa lucu kok lucu ujar
#
# 606
# negative
# label asli positive
# debatpilpres 2019 tidak harga internasional tuh doang mah dihargain kok
#
# 620
# negative
# label asli positive
# meski indonesia milik saham persen freeport sebut untung freeport jauh lebih besar
#
# 642
# positive
# label asli negative
# perintah dil digital layan sangat perlu
#
# 668
# negative
# label asli positive
# selalu tiap sempat ada tanya nikah culi kudeta apa bosan bung
#
# 687
# positive
# label asli negative
# penting jangan asal bapak senang kata sindir prabowobentengnkri asal bapak senang tau kondisi riil rakyat
#
# 700
# negative
# label asli positive
# malu - arogan - emosi - pesimis - tak taat atur debat - ngedongeng bilang lebih tni tni
#
# 715
# negative
# label asli positive
# kasihan pak tahan ketawa pecatanlebihtnidaritni
#
# 716
# negative
# label asli positive
# rendah dukung tahana rupa bukti rupa bukti bila cara tak langsung sedang hukum publik
#
# 725
# positive
# label asli negative
# bang kalau jadi presiden siapa ibu negara apa benar kita jadi negara piatu
#
# 728
# positive
# label asli negative
# lihat pak percaya tni pemerintahandilan memang nampol
#
# 739
# negative
# label asli positive
# makanya jangan ragu prabowobentengnkri prabowobentengnkri
#
# 752
# positive
# label asli negative
# pak percaya yang pecatanlebihtnidaritni pecatanlebihtnidaritni https t co jrlvbdoafw
#
# 753
# positive
# label asli negative
# kaget beneran menangkanprabowosandi april datang tps pilih
#
# 764
# positive
# label asli negative
# maju era android ke era pecatanlebihtnidaritni
#
# 795
# positive
# label asli negative
# lihat negara bagai alat maju kualitas masyarakat lihat negara bagai alat perang
#
# 805
# positive
# label asli negative
# malam minggu duduk depan layar tv nonton debat empat calon presiden semangat pak 01dilanjutkan
#
# 819
# positive
# label asli negative
# pak saya hormat lebih baik kamu daftar jadi tni biar paham percaya berani
#
# 830
# positive
# label asli negative
# pak all keluar debat malam semua umpan lawan lahap habis bahkan jawab kerap jadi serang balik
#
# 844
# positive
# label asli negative
# lihat pak percaya tni telak sekali bro tak kutik
#
# 847
# positive
# label asli negative
# awal gila antek antek dukung mulai pilpres mana hasil oleh suara sangat sedikit
#
# 860
# positive
# label asli negative
# satu yakin tni satu pesimis jadi pemerintahandilan lanjut indonesia maju
#
# 874
# positive
# label asli negative
# nyata pak debat empat ragu tni 01dilanjutkan jokowilagi
#
# 882
# positive
# label asli negative
# lama kawan lalu musuh lama tetangga lalu tak saling bicara semua karena beda pilih
#
# 888
# positive
# label asli negative
# rantai sahabat pak pak akan putus debatpilpres 2019 dengerin tuh tkn-bpn cebong kampret
#
# 889
# positive
# label asli negative
# malam pak tampil serang lugas skakmaat
#
# 893
# positive
# label asli negative
# jangan pilih pimpin bohong ingkar janji provokasi rakyat kacang lupa kulit pilih pimpin jujur
#
# 968
# positive
# label asli negative
# mantap keren moga ikut seluruh pelosok nusantara
#
# 998
# positive
# label asli negative
# bukan tidak percaya ini tni pak taruh nyawa tni lebih tni tni
